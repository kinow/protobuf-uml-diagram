# %%
# Need this for type mapping
from google.protobuf.descriptor_pb2 import FieldDescriptorProto
# And this is the compiled proto output
import ws_messages_pb2
# For string templating
from io import StringIO
import graphviz

# %%
# a mapping with values such as 1: 'double', 9: 'string', etc. to find the text value of a type
type_mapping = {number: text.lower().replace("type_", "") for text, number in FieldDescriptorProto.Type.items()}

# our compiled type actually includes .DESCRIPTOR where we can find instrospection data
types = ws_messages_pb2.DESCRIPTOR.message_types_by_name

for _type, message in types.items():
    print(f"type: [{_type}]")
    for _field in message.fields:
        message_type = _field.message_type
        if message_type:
            message_type = message_type.name
        print(f"  field: [{_field.name}] of type [{type_mapping[_field.type]}], and message type is [{message_type}]")
# Out:
# type: [PbMeta]
#   field: [title] of type [string], and message type is [None]
#   field: [description] of type [string], and message type is [None]
#   field: [URL] of type [string], and message type is [None]
#   field: [user_defined] of type [string], and message type is [None]
# type: [PbTimeZone]
#   field: [hours] of type [int32], and message type is [None]
#   field: [minutes] of type [int32], and message type is [None]
#   field: [string_basic] of type [string], and message type is [None]
#   field: [string_extended] of type [string], and message type is [None]
# type: [PbStateTotals]
#   field: [runahead] of type [int32], and message type is [None]
#   field: [waiting] of type [int32], and message type is [None]
#   field: [held] of type [int32], and message type is [None]
#   field: [queued] of type [int32], and message type is [None]
#   field: [expired] of type [int32], and message type is [None]
#   field: [ready] of type [int32], and message type is [None]
#   field: [submit_failed] of type [int32], and message type is [None]
#   field: [submit_retrying] of type [int32], and message type is [None]
#   field: [submitted] of type [int32], and message type is [None]
#   field: [retrying] of type [int32], and message type is [None]
#   field: [running] of type [int32], and message type is [None]
#   field: [failed] of type [int32], and message type is [None]
#   field: [succeeded] of type [int32], and message type is [None]
# type: [PbWorkflow]
#   field: [checksum] of type [string], and message type is [None]
#   field: [id] of type [string], and message type is [None]
#   field: [name] of type [string], and message type is [None]
#   field: [status] of type [string], and message type is [None]
#   field: [host] of type [string], and message type is [None]
#   field: [port] of type [int32], and message type is [None]
#   field: [owner] of type [string], and message type is [None]
#   field: [tasks] of type [string], and message type is [None]
#   field: [families] of type [string], and message type is [None]
#   field: [edges] of type [message], and message type is [PbEdges]
#   field: [api_version] of type [int32], and message type is [None]
#   field: [cylc_version] of type [string], and message type is [None]
#   field: [last_updated] of type [float], and message type is [None]
#   field: [meta] of type [message], and message type is [PbMeta]
#   field: [newest_runahead_cycle_point] of type [string], and message type is [None]
#   field: [newest_cycle_point] of type [string], and message type is [None]
#   field: [oldest_cycle_point] of type [string], and message type is [None]
#   field: [reloading] of type [bool], and message type is [None]
#   field: [run_mode] of type [string], and message type is [None]
#   field: [cycling_mode] of type [string], and message type is [None]
#   field: [state_totals] of type [message], and message type is [PbStateTotals]
#   field: [workflow_log_dir] of type [string], and message type is [None]
#   field: [time_zone_info] of type [message], and message type is [PbTimeZone]
#   field: [tree_depth] of type [int32], and message type is [None]
#   field: [job_log_names] of type [string], and message type is [None]
#   field: [ns_defn_order] of type [string], and message type is [None]
#   field: [states] of type [string], and message type is [None]
# type: [PbJob]
#   field: [checksum] of type [string], and message type is [None]
#   field: [id] of type [string], and message type is [None]
#   field: [submit_num] of type [int32], and message type is [None]
#   field: [state] of type [string], and message type is [None]
#   field: [task_proxy] of type [string], and message type is [None]
#   field: [submitted_time] of type [string], and message type is [None]
#   field: [started_time] of type [string], and message type is [None]
#   field: [finished_time] of type [string], and message type is [None]
#   field: [batch_sys_job_id] of type [string], and message type is [None]
#   field: [batch_sys_name] of type [string], and message type is [None]
#   field: [env_script] of type [string], and message type is [None]
#   field: [err_script] of type [string], and message type is [None]
#   field: [exit_script] of type [string], and message type is [None]
#   field: [execution_time_limit] of type [float], and message type is [None]
#   field: [host] of type [string], and message type is [None]
#   field: [init_script] of type [string], and message type is [None]
#   field: [job_log_dir] of type [string], and message type is [None]
#   field: [owner] of type [string], and message type is [None]
#   field: [post_script] of type [string], and message type is [None]
#   field: [pre_script] of type [string], and message type is [None]
#   field: [script] of type [string], and message type is [None]
#   field: [shell] of type [string], and message type is [None]
#   field: [work_sub_dir] of type [string], and message type is [None]
#   field: [batch_sys_conf] of type [string], and message type is [None]
#   field: [environment] of type [string], and message type is [None]
#   field: [directives] of type [string], and message type is [None]
#   field: [param_env_tmpl] of type [string], and message type is [None]
#   field: [param_var] of type [string], and message type is [None]
#   field: [extra_logs] of type [string], and message type is [None]
# type: [PbTask]
#   field: [checksum] of type [string], and message type is [None]
#   field: [id] of type [string], and message type is [None]
#   field: [name] of type [string], and message type is [None]
#   field: [meta] of type [message], and message type is [PbMeta]
#   field: [mean_elapsed_time] of type [float], and message type is [None]
#   field: [depth] of type [int32], and message type is [None]
#   field: [proxies] of type [string], and message type is [None]
#   field: [namespace] of type [string], and message type is [None]
# type: [PbPollTask]
#   field: [local_proxy] of type [string], and message type is [None]
#   field: [workflow] of type [string], and message type is [None]
#   field: [remote_proxy] of type [string], and message type is [None]
#   field: [req_state] of type [string], and message type is [None]
#   field: [graph_string] of type [string], and message type is [None]
# type: [PbCondition]
#   field: [task_proxy] of type [string], and message type is [None]
#   field: [expr_alias] of type [string], and message type is [None]
#   field: [req_state] of type [string], and message type is [None]
#   field: [satisfied] of type [bool], and message type is [None]
#   field: [message] of type [string], and message type is [None]
# type: [PbPrerequisite]
#   field: [expression] of type [string], and message type is [None]
#   field: [conditions] of type [message], and message type is [PbCondition]
#   field: [cycle_points] of type [string], and message type is [None]
#   field: [satisfied] of type [bool], and message type is [None]
# type: [PbTaskProxy]
#   field: [checksum] of type [string], and message type is [None]
#   field: [id] of type [string], and message type is [None]
#   field: [task] of type [string], and message type is [None]
#   field: [state] of type [string], and message type is [None]
#   field: [cycle_point] of type [string], and message type is [None]
#   field: [spawned] of type [bool], and message type is [None]
#   field: [depth] of type [int32], and message type is [None]
#   field: [job_submits] of type [int32], and message type is [None]
#   field: [latest_message] of type [string], and message type is [None]
#   field: [outputs] of type [string], and message type is [None]
#   field: [broadcasts] of type [string], and message type is [None]
#   field: [namespace] of type [string], and message type is [None]
#   field: [proxy_namespace] of type [string], and message type is [None]
#   field: [prerequisites] of type [message], and message type is [PbPrerequisite]
#   field: [jobs] of type [string], and message type is [None]
#   field: [parents] of type [string], and message type is [None]
# type: [PbFamily]
#   field: [checksum] of type [string], and message type is [None]
#   field: [id] of type [string], and message type is [None]
#   field: [name] of type [string], and message type is [None]
#   field: [meta] of type [message], and message type is [PbMeta]
#   field: [depth] of type [int32], and message type is [None]
#   field: [proxies] of type [string], and message type is [None]
#   field: [parents] of type [string], and message type is [None]
#   field: [child_tasks] of type [string], and message type is [None]
#   field: [child_families] of type [string], and message type is [None]
# type: [PbFamilyProxy]
#   field: [checksum] of type [string], and message type is [None]
#   field: [id] of type [string], and message type is [None]
#   field: [cycle_point] of type [string], and message type is [None]
#   field: [name] of type [string], and message type is [None]
#   field: [family] of type [string], and message type is [None]
#   field: [state] of type [string], and message type is [None]
#   field: [depth] of type [int32], and message type is [None]
#   field: [parents] of type [string], and message type is [None]
#   field: [child_tasks] of type [string], and message type is [None]
#   field: [child_families] of type [string], and message type is [None]
# type: [PbEdge]
#   field: [checksum] of type [string], and message type is [None]
#   field: [id] of type [string], and message type is [None]
#   field: [tail_node] of type [string], and message type is [None]
#   field: [head_node] of type [string], and message type is [None]
#   field: [suicide] of type [bool], and message type is [None]
#   field: [cond] of type [bool], and message type is [None]
# type: [PbEdges]
#   field: [id] of type [string], and message type is [None]
#   field: [edges] of type [string], and message type is [None]
#   field: [workflow_polling_tasks] of type [message], and message type is [PbPollTask]
#   field: [leaves] of type [string], and message type is [None]
#   field: [feet] of type [string], and message type is [None]
# type: [PbEntireWorkflow]
#   field: [workflow] of type [message], and message type is [PbWorkflow]
#   field: [tasks] of type [message], and message type is [PbTask]
#   field: [task_proxies] of type [message], and message type is [PbTaskProxy]
#   field: [jobs] of type [message], and message type is [PbJob]
#   field: [families] of type [message], and message type is [PbFamily]
#   field: [family_proxies] of type [message], and message type is [PbFamilyProxy]
#   field: [edges] of type [message], and message type is [PbEdge]

# %%
# This dictionary is used to map the type string,
# to the label index we used in the UML diagram, used later to link entities
message_mapping = {}

entry_index = 2
for _type, message in types.items():
    message_mapping[_type] = entry_index
    entry_index += 1

print(message_mapping)
# Out:
# {'PbMeta': 2, 'PbTimeZone': 3, 'PbStateTotals': 4, 'PbWorkflow': 5, 'PbJob': 6, 'PbTask': 7, 'PbPollTask': 8, 'PbCondition': 9, 'PbPrerequisite': 10, 'PbTaskProxy': 11, 'PbFamily': 12, 'PbFamilyProxy': 13, 'PbEdge': 14, 'PbEdges': 15, 'PbEntireWorkflow': 16}

# %%
# Generate dot syntax to display a class diagram
# Refs:
# - https://fsteeg.wordpress.com/2006/11/17/uml-class-diagrams-with-graphviz/
# - http://www.ffnn.nl/pages/articles/media/uml-diagrams-using-graphviz-dot.php

template = StringIO()

template.write(f"""
digraph "Protobuf UML class diagram" {{
    fontname = "Bitstream Vera Sans"
    fontsize = 8

    node [
        fontname = "Bitstream Vera Sans"
        fontsize = 8
        shape = "record"
        style=filled
        fillcolor=gray95
    ]

    edge [
        fontname = "Bitstream Vera Sans"
        fontsize = 8

    ]

""")

relationships = []

entry_index = 2
for _type, message in types.items():
    type_template_text = StringIO()
    type_template_text.write(f"""    {entry_index}[label = "{{{_type}|""")  #]\n""")
    fields = []
    for _field in message.fields:
        message_type = _field.message_type
        field_type = type_mapping[_field.type] # this will be 'message' if referencing another protobuf message type
        
        if message_type:
            this_node = message_mapping[_type]
            that_node = message_mapping[message_type.name]
            relationships.append(f"{this_node}->{that_node}")
            field_type = message_type.name # so we replace the 'message' token by the actual name
        
        fields.append(f"+ {_field.name}:{field_type}")
    
    # add fields
    type_template_text.write("\\n".join(fields))
    type_template_text.write("}\"]\n")
    entry_index += 1
    template.write(type_template_text.getvalue())
    
    type_template_text.close()

# add relationships
template.write("\n")
template.write("\n".join(relationships))

template.write("\n}")
template_text = template.getvalue()
template.close()

print(template_text)
# Out:
# digraph "Protobuf UML class diagram" {
#     fontname = "Bitstream Vera Sans"
#     fontsize = 8
#
#     node [
#         fontname = "Bitstream Vera Sans"
#         fontsize = 8
#         shape = "record"
#         style=filled
#         fillcolor=gray95
#     ]
#
#     edge [
#         fontname = "Bitstream Vera Sans"
#         fontsize = 8
#
#     ]
#
#     2[label = "{PbMeta|+ title:string\n+ description:string\n+ URL:string\n+ user_defined:string}"]
#     3[label = "{PbTimeZone|+ hours:int32\n+ minutes:int32\n+ string_basic:string\n+ string_extended:string}"]
#     4[label = "{PbStateTotals|+ runahead:int32\n+ waiting:int32\n+ held:int32\n+ queued:int32\n+ expired:int32\n+ ready:int32\n+ submit_failed:int32\n+ submit_retrying:int32\n+ submitted:int32\n+ retrying:int32\n+ running:int32\n+ failed:int32\n+ succeeded:int32}"]
#     5[label = "{PbWorkflow|+ checksum:string\n+ id:string\n+ name:string\n+ status:string\n+ host:string\n+ port:int32\n+ owner:string\n+ tasks:string\n+ families:string\n+ edges:PbEdges\n+ api_version:int32\n+ cylc_version:string\n+ last_updated:float\n+ meta:PbMeta\n+ newest_runahead_cycle_point:string\n+ newest_cycle_point:string\n+ oldest_cycle_point:string\n+ reloading:bool\n+ run_mode:string\n+ cycling_mode:string\n+ state_totals:PbStateTotals\n+ workflow_log_dir:string\n+ time_zone_info:PbTimeZone\n+ tree_depth:int32\n+ job_log_names:string\n+ ns_defn_order:string\n+ states:string}"]
#     6[label = "{PbJob|+ checksum:string\n+ id:string\n+ submit_num:int32\n+ state:string\n+ task_proxy:string\n+ submitted_time:string\n+ started_time:string\n+ finished_time:string\n+ batch_sys_job_id:string\n+ batch_sys_name:string\n+ env_script:string\n+ err_script:string\n+ exit_script:string\n+ execution_time_limit:float\n+ host:string\n+ init_script:string\n+ job_log_dir:string\n+ owner:string\n+ post_script:string\n+ pre_script:string\n+ script:string\n+ shell:string\n+ work_sub_dir:string\n+ batch_sys_conf:string\n+ environment:string\n+ directives:string\n+ param_env_tmpl:string\n+ param_var:string\n+ extra_logs:string}"]
#     7[label = "{PbTask|+ checksum:string\n+ id:string\n+ name:string\n+ meta:PbMeta\n+ mean_elapsed_time:float\n+ depth:int32\n+ proxies:string\n+ namespace:string}"]
#     8[label = "{PbPollTask|+ local_proxy:string\n+ workflow:string\n+ remote_proxy:string\n+ req_state:string\n+ graph_string:string}"]
#     9[label = "{PbCondition|+ task_proxy:string\n+ expr_alias:string\n+ req_state:string\n+ satisfied:bool\n+ message:string}"]
#     10[label = "{PbPrerequisite|+ expression:string\n+ conditions:PbCondition\n+ cycle_points:string\n+ satisfied:bool}"]
#     11[label = "{PbTaskProxy|+ checksum:string\n+ id:string\n+ task:string\n+ state:string\n+ cycle_point:string\n+ spawned:bool\n+ depth:int32\n+ job_submits:int32\n+ latest_message:string\n+ outputs:string\n+ broadcasts:string\n+ namespace:string\n+ proxy_namespace:string\n+ prerequisites:PbPrerequisite\n+ jobs:string\n+ parents:string}"]
#     12[label = "{PbFamily|+ checksum:string\n+ id:string\n+ name:string\n+ meta:PbMeta\n+ depth:int32\n+ proxies:string\n+ parents:string\n+ child_tasks:string\n+ child_families:string}"]
#     13[label = "{PbFamilyProxy|+ checksum:string\n+ id:string\n+ cycle_point:string\n+ name:string\n+ family:string\n+ state:string\n+ depth:int32\n+ parents:string\n+ child_tasks:string\n+ child_families:string}"]
#     14[label = "{PbEdge|+ checksum:string\n+ id:string\n+ tail_node:string\n+ head_node:string\n+ suicide:bool\n+ cond:bool}"]
#     15[label = "{PbEdges|+ id:string\n+ edges:string\n+ workflow_polling_tasks:PbPollTask\n+ leaves:string\n+ feet:string}"]
#     16[label = "{PbEntireWorkflow|+ workflow:PbWorkflow\n+ tasks:PbTask\n+ task_proxies:PbTaskProxy\n+ jobs:PbJob\n+ families:PbFamily\n+ family_proxies:PbFamilyProxy\n+ edges:PbEdge}"]
#
# 5->15
# 5->2
# 5->4
# 5->3
# 7->2
# 10->9
# 11->10
# 12->2
# 15->8
# 16->5
# 16->7
# 16->11
# 16->6
# 16->12
# 16->13
# 16->14
# }

# %%
from graphviz import Source

src = Source(template_text)
src
src.render('/tmp/uml')
# Out:
# '/tmp/uml.pdf'
